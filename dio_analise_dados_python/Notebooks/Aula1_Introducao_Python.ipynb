# %%
print("Olá Mundo")
# Out:
# Olá Mundo

# %%
print("Estou aprendendo Python")
# Out:
# Estou aprendendo Python

# %%
"Estou aprendendo Python"
# Out:
# 'Estou aprendendo Python'

# %%
1+1
# Out:
# 2

# %%
10-2
# Out:
# 8

# %%
#Esse é um comentário em Python

# %%
#Multiplicação
2*2
# Out:
# 4

# %%
#Divisão
10/2
# Out:
# 5.0

# %%
a = 4
b = 6

# %%
a+b
# Out:
# 10

# %%
#Criando variável do tipo string
frase = "Python para analisé de dados"

# %%
frase[0]
# Out:
# 'P'

# %%
frase[0:10]
# Out:
# 'Python par'

# %%
frase[10:]
# Out:
# 'a analisé de dados'

# %%
frase[:17]
# Out:
# 'Python para anali'

# %%
frase.count("dados")
# Out:
# 1

# %%
frase.lower()
# Out:
# 'python para analisé de dados'

# %%
frase = frase.upper()

# %%
frase.replace("Python","Frases")
# Out:
# 'FRASES PARA ANALISÉ DE DADOS'

# %%
frase
# Out:
# 'FRASES PARA ANALISÉ DE DADOS'
